# %%
import pandas as pd
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from xgboost import plot_importance

# %%
df = pd.read_csv('training_cleaned.csv')

# %%
train, val = train, val = train_test_split(df, test_size=0.20, random_state=11)

x_train = train.drop(columns=['Classes_num'])
y_train = train['Classes_num'].values

x_val = val.drop(columns=['Classes_num'])
y_val = val['Classes_num'].values

# %%
xgb = XGBClassifier(n_estimators=100)
xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
x_train.shape
# Out:
# (4800, 18)

# %%
x_val.shape
# Out:
# (1200, 18)

# %%
xgb.score(x_train, y_train)
# Out:
# 0.956875

# %%
xgb.score(x_val, y_val)
# Out:
# 0.9341666666666667

# %%
xgb.feature_importances_
# Out:
# array([0.02168938, 0.2847534 , 0.06478158, 0.31796408, 0.04562921,
#        0.13732454, 0.00464498, 0.03333398, 0.        , 0.        ,
#        0.01211806, 0.02049715, 0.01233834, 0.00171184, 0.01911244,
#        0.        , 0.        , 0.02410097], dtype=float32)

# %%
plt.barh(x_train.columns, xgb.feature_importances_)
# Out:
# <BarContainer object of 18 artists>

# %%
sorted_idx = xgb.feature_importances_.argsort()
plt.barh(x_train.columns[sorted_idx], xgb.feature_importances_[sorted_idx])
plt.xlabel("Xgboost Feature Importance")
# Out:
# Text(0.5, 0, 'Xgboost Feature Importance')

# %%
feature_importances = pd.DataFrame(xgb.feature_importances_, 
                                   index = x_train.columns,  
                                   columns= ['importance']).sort_values('importance', ascending=False)

# %%
feature_importances
# Out:
#                      importance
# TT4                    0.317964
# TSH                    0.284753
# FTI                    0.137325
# T3                     0.064782
# T4U                    0.045629
# Thyroxine_num          0.033334
# Tumor_num              0.024101
# Age                    0.021689
# Pregnant_num           0.020497
# Query_Hyper_num        0.019112
# Thyroid_Surg_num       0.012338
# Sick_num               0.012118
# Sex_num                0.004645
# Query_Hypo_num         0.001712
# Query_Thyroxine_num    0.000000
# Lithium_num            0.000000
# Goiter_num             0.000000
# Antithyroid_num        0.000000
